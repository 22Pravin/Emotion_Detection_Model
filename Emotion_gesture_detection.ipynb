# %%
pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 31.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 9.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 11.0 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116934 sha256=6c94bc59db8962a7a68cceb351d3472b401ce8d698640e0fcce76ab52afe9f14
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# ...

# %%
from deepface import DeepFace
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
import cv2
import matplotlib.pyplot as plt
img1=cv2.imread("/content/passport photo.jpg")
plt.imshow(img1)

# %%
detect_face=DeepFace.detectFace(img_path=img1)
plt.imshow(detect_face)
# Out:
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.

# %%
outcome=DeepFace.analyze(img1,actions=['emotion','age','gender'])
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 76.1MB/s]
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
# 100%|██████████| 539M/539M [00:02<00:00, 228MB/s]
# gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: /root/.deepface/weights/gender_model_weights.h5
# 100%|██████████| 537M/537M [00:01<00:00, 272MB/s]
# Action: gender: 100%|██████████| 3/3 [00:02<00:00,  1.34it/s]

# %%
print(outcome)
# Out:
# [{'emotion': {'angry': 0.0014851114428893197, 'disgust': 3.38587241577315e-08, 'fear': 0.002194364969909657, 'happy': 91.99673533439636, 'sad': 0.19011266995221376, 'surprise': 0.29992954805493355, 'neutral': 7.5095392763614655}, 'dominant_emotion': 'happy', 'region': {'x': 212, 'y': 251, 'w': 697, 'h': 697}, 'age': 27, 'gender': {'Woman': 0.234368653036654, 'Man': 99.76563453674316}, 'dominant_gender': 'Man'}]
